# %%
# 查看所有子目录，选择一个子目录即可
# !gsutil ls 'gs://mdgen-public/4AA_sims/'
# Out:
# gs://mdgen-public/4AA_sims/
# gs://mdgen-public/4AA_sims/AADY/
# gs://mdgen-public/4AA_sims/AAFS/
# gs://mdgen-public/4AA_sims/AAKD/
# gs://mdgen-public/4AA_sims/AAKQ/
# gs://mdgen-public/4AA_sims/AAMR/
# gs://mdgen-public/4AA_sims/AAPH/
# gs://mdgen-public/4AA_sims/AASF/
# gs://mdgen-public/4AA_sims/AAWQ/
# gs://mdgen-public/4AA_sims/AAYG/
# gs://mdgen-public/4AA_sims/AAYQ/
# gs://mdgen-public/4AA_sims/ACDG/
# gs://mdgen-public/4AA_sims/ACGA/
# gs://mdgen-public/4AA_sims/ACLN/
# gs://mdgen-public/4AA_sims/ACTC/
# gs://mdgen-public/4AA_sims/ACWP/
# gs://mdgen-public/4AA_sims/ADDC/
# gs://mdgen-public/4AA_sims/ADHT/
# gs://mdgen-public/4AA_sims/ADIG/
# gs://mdgen-public/4AA_sims/ADKN/
# gs://mdgen-public/4AA_sims/ADMI/
# gs://mdgen-public/4AA_sims/ADNF/
# gs://mdgen-public/4AA_sims/ADPG/
# gs://mdgen-public/4AA_sims/ADRK/
# gs://mdgen-public/4AA_sims/ADRM/
# gs://mdgen-public/4AA_sims/ADSA/
# gs://mdgen-public/4AA_sims/ADSC/
# gs://mdgen-public/4AA_sims/ADSL/
# ...

# %%
key = 'AAKQ'
# 可选 AAKQ  AAKD AADY AAFS AAPH ....,
root_dir1 = 'gs://mdgen-public/4AA_sims'
root_dir2 = 'gs://mdgen-public/4AA_sims_implicit'

data_dir1 = root_dir1 + f"/{key}"
data_dir2 = root_dir2 + f"/{key}"
print(data_dir1)
print(data_dir2)
# Out:
# gs://mdgen-public/4AA_sims/AAKQ
# gs://mdgen-public/4AA_sims_implicit/AAKQ

# %%
# !gsutil ls 'gs://mdgen-public/4AA_sims/AAKQ'
# !gsutil ls 'gs://mdgen-public/4AA_sims_implicit/AAKQ'
# Out:
# gs://mdgen-public/4AA_sims/AAKQ/AAKQ.out
# gs://mdgen-public/4AA_sims/AAKQ/AAKQ.pdb
# gs://mdgen-public/4AA_sims/AAKQ/AAKQ.xtc
# gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.out
# gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.pdb
# gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.xtc

# %%
# !mkdir -p 'data/4AA_sims/AAKQ'

# %%
# !gsutil -m rsync -r 'gs://mdgen-public/4AA_sims/AAKQ' 'data/4AA_sims/AAKQ'
# Out:
# Building synchronization state...
# Starting synchronization...
# Copying gs://mdgen-public/4AA_sims/AAKQ/AAKQ.out...
# Copying gs://mdgen-public/4AA_sims/AAKQ/AAKQ.xtc...
# Copying gs://mdgen-public/4AA_sims/AAKQ/AAKQ.pdb...
#
# Operation completed over 3 objects/198.6 MiB.

# %%
# !mkdir -p 'data/4AA_sims_implicit/AAKQ'

# %%
# !gsutil -m rsync -r 'gs://mdgen-public/4AA_sims_implicit/AAKQ' 'data/4AA_sims_implicit/AAKQ'
# Out:
# Building synchronization state...
# Starting synchronization...
# Copying gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.xtc...
# Copying gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.out...
# Copying gs://mdgen-public/4AA_sims_implicit/AAKQ/AAKQ.pdb...
#
# Operation completed over 3 objects/197.7 MiB.
