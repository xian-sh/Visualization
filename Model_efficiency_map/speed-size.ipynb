# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(5,4))
plt.scatter(7.09, 46.16, marker='o', color='#faff72', s=4794.6, label='MS-2D-TAN(TPAMI\'21)')
plt.scatter(16.39, 44.51, marker='o', color='#00e500', s=216.2, label='2D-TAN(AAAI\'20)')

plt.scatter(23.81, 48.02, marker='o', color='#70f3ff', s=371.9, label='MSAT(CVPR\'21)')
plt.scatter(71.43, 48.59, marker='o', color='#d6ecf0', s=1522.2, label='MMN\n(AAAI\'22)')
plt.scatter(8.70, 47.92, marker='o', color='#b0a4e3', s=51.2, label='MGPN\n(SIGIR\'22)')
plt.scatter(26.32, 50.44, marker='o', color='#ffc773', s=1522.5, label='PTRM(AAAI\'23)')
plt.scatter(111.11, 60.75, marker='o', color='#ffb3a7', s=771.6, label='LRTNet')

plt.text(20, 44.2, '2D-TAN', )
plt.text(1, 46,'MS-2D-TAN',)
plt.text(28, 47.5, 'MSAT', )
plt.text(81, 48.5, 'MMN', )
plt.text(1, 49.5, 'MGPN', )
plt.text(20, 53.4, 'PTRM',)
plt.text(104, 62.3, 'LRTNet',color='r')

plt.text(38, 44.2, '(AAAI\'20)', color='grey')
plt.text(28, 46,'(TPAMI\'21)',  color='grey')
plt.text(41, 47.5, '(CVPR\'21)', color='grey')
plt.text(81, 47.5, '(AAAI\'22)', color='grey')
plt.text(1, 48.5, '(SIGIR\'22)', color='grey')
plt.text(20, 52.4, '(AAAI\'23)', color='grey')



plt.plot([26.32,118], [50.44, 50.44], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(111.11, 50.4), xytext=(111.11, 59.6), arrowprops={'arrowstyle': '<-', 'lw': 1})
plt.text(113, 51.5,'10.31% better',color='r',rotation=90)

plt.plot([71.43, 71.43], [48.59,62], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(71.43, 60.75), xytext=(105.9, 60.75), arrowprops={'arrowstyle': '<-', 'lw': 1})
plt.text(73, 59.5,'1.56x faster',color='r')

plt.scatter(7, 62, marker='o', color='lavender', s=200)
plt.text(3, 58.8, '20M')


plt.scatter(22, 62, marker='o', color='lavender', s=800)
plt.text(17, 58.8, '80M')


plt.scatter(43, 62, marker='o', color='lavender', s=1600)
plt.text(36, 58.8, '160M')



plt.ylim(43.5,64)
plt.xlim(0,125)
plt.xlabel('Speed (Queries per second)')
plt.ylabel('R@1,IoU@0.5' )
plt.xticks(ticks=[8, 16, 25, 71, 111], labels=['8', '16', '25', '71', '111'])
plt.yticks(ticks=list(range(44, 64, 2)), labels=[str(i) for i in range(44, 64, 2)])
# plt.legend(loc='best')
plt.savefig('efficient_name.pdf', dpi=300)
plt.show()
