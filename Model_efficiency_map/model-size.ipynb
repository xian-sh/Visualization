# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(4.5,3.5))
plt.scatter(5.12, 47.92, marker='o', color='#d6ecf0', s=200, label='MGPN\n(SIGIR\'22)')
plt.scatter(21.62, 44.51, marker='o', color='#ffb3a7', s=200, label='2D-TAN(AAAI\'20)')
plt.scatter(37.19, 48.02, marker='o', color='#70f3ff', s=200, label='MSAT(CVPR\'21)')
plt.scatter(77.16, 63.43, marker='o', color='#ff4777', s=200, label='LRTNet')
plt.scatter(152.22, 48.59, marker='o', color='#b0a4e3', s=200, label='MMN\n(AAAI\'22)')
plt.scatter(152.25, 50.44, marker='o', color='#ffc773', s=200, label='PTRM(AAAI\'23)')
plt.scatter(479.46, 46.16, marker='o', color='#7fecad', s=200, label='MS-2D-TAN(TPAMI\'21)')


plt.text(1, 46, 'MGPN')
# plt.text(1, 57.3, 'MAE')
plt.text(40, 44.2, '2D-TAN')
plt.text(2, 49.1, 'MSAT')
plt.text(30, 64.8, 'Our LRTNet',color='r')
plt.text(168, 48, 'MMN')
plt.text(170, 50, 'PTRM')
plt.text(350, 46.5,'MS-2D-TAN')



plt.text(63, 46, '(SIGIR\'22)', color='grey')
plt.text(115, 44.2, '(AAAI\'20)', color='grey')
plt.text(56, 49.1, '(CVPR\'21)', color='grey')
plt.text(219, 48, '(AAAI\'22)', color='grey')
plt.text(226, 50, '(AAAI\'23)', color='grey')
plt.text(350, 45.2,'(TPAMI\'21)',  color='grey')

plt.plot([20,152.25], [50.44,50.44], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(76.52, 50.44), xytext=(76.52, 62.8), arrowprops={'arrowstyle': '<-', 'lw': 1})
plt.text(85, 56.5,'12.99% better',color='r')

plt.plot([479.46,479.46], [46.16,65], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(86, 63.43), xytext=(479.46, 63.43), arrowprops={'arrowstyle': '->', 'lw': 1})
plt.text(230, 61.7,'6.12 x smaller',color='r')


plt.ylim(43,67)
plt.xlabel('Model Parameters($\\times 10^6$)')
plt.ylabel('R@1,IoU@0.5')

plt.savefig('efficient_name.pdf', bbox_inches='tight', dpi=300)
plt.show()
