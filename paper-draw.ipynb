# %%
import matplotlib.pyplot as plt


# plt.figure(figsize=(6,4.5))
plt.scatter(7.09, 46.16, marker='o', color='lightgreen', s=4794.6, label='MS-2D-TAN(TPAMI\'21)')
plt.scatter(16.39, 44.51, marker='o', color='green', s=216.2, label='2D-TAN(AAAI\'20)')

plt.scatter(23.81, 48.02, marker='o', color='lightgreen', s=371.9, label='MSAT(CVPR\'21)')
plt.scatter(71.43, 48.59, marker='o', color='pink', s=1522.2, label='MMN\n(AAAI\'22)')
plt.scatter(8.70, 47.92, marker='o', color='green', s=51.2, label='MGPN\n(SIGIR\'22)')
plt.scatter(26.32, 50.44, marker='o', color='pink', s=1522.5, label='PTRM(AAAI\'23)')
plt.scatter(111.11, 60.75, marker='o', color='pink', s=765.2, label='Our UniSDNet')

plt.text(20, 44.2, '2D-TAN', fontsize=14)
plt.text(1, 46,'MS-2D-TAN', fontsize=14)
plt.text(28, 47.5, 'MSAT', fontsize=14)
plt.text(79, 48.5, 'MMN', fontsize=14)
plt.text(1, 49.5, 'MGPN', fontsize=14)
plt.text(20, 53.2, 'PTRM', fontsize=14)
plt.text(94, 62.3, 'UniSDNet-M',color='r', fontsize=14)

plt.text(38, 44.2, '(AAAI\'20)', fontsize=14, color='grey')
plt.text(28, 46,'(TPAMI\'21)', fontsize=14, color='grey')
plt.text(41, 47.5, '(CVPR\'21)', fontsize=14, color='grey')
plt.text(79, 47.5, '(AAAI\'22)', fontsize=14, color='grey')
plt.text(1, 48.5, '(SIGIR\'22)', fontsize=14, color='grey')
plt.text(20, 52.2, '(AAAI\'23)', fontsize=14, color='grey')
# plt.text(53, 61.5, 'Our UniSDNet',color='r', fontsize=14)


plt.plot([26.32,118], [50.44, 50.44], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(111.11, 50.4), xytext=(111.11, 59.8), arrowprops={'arrowstyle': '<-', 'lw': 1})
plt.text(105, 51.5,'10.31% better',color='r', fontsize=14, rotation=90)

plt.plot([71.43, 71.43], [48.59,62], linestyle='dashed', color='grey', linewidth=1)
plt.annotate('', xy=(71.43, 60.75), xytext=(107.5, 60.75), arrowprops={'arrowstyle': '<-', 'lw': 1})
plt.text(73, 59.5,'1.56x faster',color='r', fontsize=14)

plt.scatter(7, 62, marker='o', color='pink', s=200)
plt.text(10, 61.7, 'Multi-query', fontsize=14)

plt.scatter(7, 60.3, marker='o', color='lightgreen', s=200)
plt.scatter(13, 60.3, marker='o', color='green', s=200)
plt.text(16, 59.9, 'Single-query', fontsize=14)

# plt.scatter(7, 58.4, marker='o', color='lightgrey', s=200)
# plt.text(10, 58.0, 'Size of 20M', fontsize=14)
plt.annotate('', xy=(4, 57), xytext=(50, 57), arrowprops={'arrowstyle': '-', 'lw': 1, 'color': 'gray'})

plt.annotate('', xy=(9, 56.9), xytext=(9, 57.5), arrowprops={'arrowstyle': '-', 'lw': 1, 'color': 'gray'})

plt.annotate('', xy=(14, 56.9), xytext=(14, 57.5), arrowprops={'arrowstyle': '-', 'lw': 1, 'color': 'gray'})

plt.annotate('', xy=(24, 56.9), xytext=(24, 57.5), arrowprops={'arrowstyle': '-', 'lw': 1, 'color': 'gray'})

plt.annotate('', xy=(44, 56.9), xytext=(44, 57.5), arrowprops={'arrowstyle': '-', 'lw': 1, 'color': 'gray'})


plt.text(5, 58.2, 'Diameter', fontsize=12, color='grey')

plt.text(7.8, 56.1, '2', fontsize=12, color='grey')
plt.text(12.7, 56.1, '8', fontsize=12, color='grey')
plt.text(21.2, 56.1, '32', fontsize=12, color='grey')
plt.text(41.1, 56.1, '64 $\\times$10M', fontsize=12, color='grey')



plt.ylim(43.5,64)
plt.xlim(0,125)
plt.xlabel('Speed (Queries per second)', fontsize=14)
plt.ylabel('R@1,IoU0.5', fontsize=14)
plt.xticks(ticks=[8, 16, 25, 71, 111], labels=['8', '16', '25', '71', '111'], fontsize=14)
plt.yticks(ticks=list(range(44, 64, 2)), labels=[str(i) for i in range(44, 64, 2)], fontsize=14)
# plt.legend(loc='best')
plt.savefig('efficient_name.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]

y = [52.35,57.3,59.27,60.28,60.75]

fig = plt.figure(figsize=(3,2))
plt.plot(x, y,  marker='^', markersize=8, linestyle='-', linewidth=2, markerfacecolor='deepskyblue', markeredgecolor='deepskyblue', color='deepskyblue')

for i, value in enumerate(y):
    plt.text(x[i]-0.3, y[i]+1, str(value), fontsize=9, ha='left', va='bottom')

plt.ylim(46,64)
plt.xlim(0.5,5.5)
plt.tick_params(direction='in')
# ax = plt.gca()

# # 隐藏上边框和右边框
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)

plt.xticks(ticks=[1, 2, 3, 4, 5], labels=['Single', 'm$\leq$3', 'm$\leq$5', 'm$\leq$8', 'Full'])

# 设置Y轴的特定刻度位置和标签
plt.yticks(ticks=[48, 53, 58, 62], labels=['48', '53', '58', '62'])

# plt.axhline(y=48.59, color='gray', linestyle='--')
# plt.text(4, 48.9, 'MMN(Full)', color='black', ha='center', va='bottom')

plt.axhline(y=48.02, color='gray', linestyle='--')
plt.text(4, 48.6, 'MSAT(Single)', color='black', ha='center', va='bottom')

plt.text(1, 48.4, '48.02', color='black', ha='center', va='bottom')

plt.xlabel("Training Query Number")
plt.ylabel("R@1,IoU@0.5")
# plt.tight_layout()
plt.savefig('act_query_text.pdf', format='pdf', bbox_inches='tight', dpi=300, )
plt.show()

# %%
pip install brokenaxes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from brokenaxes import brokenaxes
x = [1, 2, 3, 4, 5]

y = [47.82,52.62,54.77,55.43,56.29]

fig = plt.figure(figsize=(3,2))

ax = brokenaxes(ylims=((29,35),(46,60)), xlims=((0.5,5.5),), hspace=0.05, despine=False)

ax.plot(x, y,  marker='o', markersize=8, linestyle='-', linewidth=2, markerfacecolor='none', markeredgecolor='orange', color='orange')

        
for i, value in enumerate(y):
    ax.text(x[i]-0.3, y[i]+1, str(value), fontsize=9)

# ax.set_ylim(29,60)
# ax.set_xlim(-0.5,6)
ax.tick_params(direction='in')
# ax = plt.gca()

# # 隐藏上边框和右边框
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)

ax.set_xticks(ticks=[1, 2, 3, 4, 5], labels=['Single', 'm$\leq$3', 'm$\leq$5', 'm$\leq$8', 'Full'])

# 设置Y轴的特定刻度位置和标签
# plt.yticks(ticks=[48, 53, 58, 62], labels=['48', '53', '58', '62'])

# plt.axhline(y=42.74, color='gray', linestyle='--')
# plt.text(4, 43, 'MMN(Full)', color='black', ha='center', va='bottom')

# plt.text(1, 43, '42.74', color='black', ha='center', va='bottom')

ax.axhline(y=30.38, color='gray', linestyle='--')
ax.text(4, 31, 'VSLNet(Single)', color='black', ha='center', va='bottom')

ax.text(1, 31, '30.38', color='black', ha='center', va='bottom')



ax.set_xlabel("Training Query Number")
plt.ylabel("R@1,IoU@0.5", labelpad=20)


# plt.tight_layout()
plt.savefig('act_query_audio.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from brokenaxes import brokenaxes
import warnings

warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

# 37.07 37.44 38.46 38.07 38.57 38.92 38.99
# 31.26 31.51 31.37 31.97 30.96 33.27 33.74

data = pd.DataFrame({
    'Numbers': ['Static', 'GCN', 'GAT', 'D', 'MLP', 'DTFNet'],
    's1 Accuracy': [55.18, 58.14, 58.78, 59.16, 59.52, 60.75],
    's2 Accuracy': [47.82, 53.29, 53.96, 55.03, 54.95, 56.29]
})
plt.figure(figsize=(6.5,4))
bax = brokenaxes(ylims=((0, 1),(45, 67)), hspace=0.05, despine=False)

x = np.array([0, 1, 2, 3, 4, 5])
bax.bar(x-0.2, data['s1 Accuracy'], width=0.4, color='lightblue', label='NLVG')
bax.bar(x+0.2, data['s2 Accuracy'], width=0.4, color='oldlace', label='SLVG')

bax.plot(x-0.2, data['s1 Accuracy'], color='black', linestyle='--', linewidth=2, marker='o')
bax.plot(x+0.2, data['s2 Accuracy'], color='black', linestyle='--', linewidth=2, marker='o')

bax.scatter(4.8,60.75, c='red', zorder=3)

bax.scatter(5.2,56.29, c='red', zorder=3)

bax.axvline(x=0.5, color='gray', linestyle='--' )
bax.axvline(x=2.5, color='gray', linestyle='--' )

bax.text(4.6, 61.3, '60.75', color='red', fontsize=12)  # full
bax.text(1.6, 59.5, '58.78', fontsize=12)   # gat
bax.text(0.6, 59, '58.14', fontsize=12)   # gcn
bax.text(3.6, 60.4, '59.16', fontsize=12)   # mlp
bax.text(2.6, 60, '59.52', fontsize=12)   # d
# bax.text(0.5, 38, '37.44', fontsize=11)
bax.text(-0.4, 53.5, '55.18', fontsize=12)  # no

bax.text(4.9, 57, '56.29', color='red', fontsize=11)  # full
bax.text(1.8, 54.5, '53.96', fontsize=12)    # gat
bax.text(0.8, 54, '53.29', fontsize=12)    # gcn
bax.text(3.9, 55.5, '54.95', fontsize=12)  # mlp
bax.text(2.9, 55.5, '55.03', fontsize=12)    # d
# bax.text(0.75, 32, '31.51', fontsize=11)
bax.text(-0.15, 46, '47.82', fontsize=12)  # no

# plt.text(6, 0, 'DTFNet', fontsize=11,color='red')

x_ticks = np.arange(6)
x_ticklabels = ['','w/o Graph', 'GCN', 'GAT', 'D', 'MLP', 'Ours']
bax.set_xticks(x_ticks)
bax.set_xticklabels(x_ticklabels)
# bax.set_ylabel('R@1,IoU0.5', fontsize=11)
bax.tick_params(axis='both', direction='in', labelsize=12)
bax.legend(fontsize=12, ncol=2)

plt.savefig('gnn.pdf', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 构造示例数据
x = np.arange(1, 7)  # x轴数据点

m1 = np.array([74.50, 75.62, 74.15, 75.09, 74.78, 75.33])

n1 = 65.05

m2 = np.array([59.23, 60.75, 58.85, 59.82, 59.90, 60.28])

n2 = 48.59

m3 = np.array([38.22, 38.88, 37.78, 38.32, 38.11, 38.81])

n3 = 29.26
fig = plt.figure()
ax = plt.subplot(1, 1, 1)
# 绘制折线图
plt.plot(x, m1, marker='o', linestyle='-', label='UniSDNet', color='black')
# plt.errorbar(x, m1, yerr=s1, linestyle='None', marker='None', color='black')
# # 绘制方差区域
# plt.fill_between(x, m1 - s1, m1 + s1, color='lightblue', alpha=0.3)


# 绘制折线图
plt.plot(x, m2, marker='o', linestyle='-',   color='black')
# plt.errorbar(x, m2, yerr=s2, linestyle='None', marker='None', color='black')
# # 绘制方差区域
# plt.fill_between(x, m2 - s2, m2 + s2, color='lightblue', alpha=0.3)


plt.plot(x, m3, marker='o', linestyle='-', color='black')
# plt.errorbar(x, m3, yerr=s3, linestyle='None', marker='None', color='black')
# # 绘制方差区域
# plt.fill_between(x, m3 - s3, m3 + s3, color='lightblue', alpha=0.3)

plt.scatter(2,75.62, c='red', zorder=3)
# plt.errorbar(2, 73.68133333, yerr=1.757156252, color='red',zorder=4)

plt.scatter(2,60.75, c='red', zorder=3)
# plt.errorbar(2, 57.704, yerr=3.012689354, color='red',zorder=4)

plt.scatter(2,38.88, c='red', zorder=3)
# plt.errorbar(2, 36.03533333, yerr=3.188167558, color='red',zorder=4)


plt.text(1.8,77,'75.62',color='red')
plt.text(1.8,62,'60.75',color='red')
plt.text(1.8,40,'38.88',color='red')


plt.text(0.8,76,'74.50')
plt.text(0.8,61,'59.23')
plt.text(0.8,40,'38.22')

plt.text(2.8,76,'74.15')
plt.text(2.8,61,'58.85')
plt.text(2.8,40,'37.78')


plt.text(3.8,76,'75.09')
plt.text(3.8,61,'59.82')
plt.text(3.8,40,'38.32')

plt.text(4.8,76,'74.78')
plt.text(4.8,61,'59.90')
plt.text(4.8,40,'38.11')

plt.text(5.8,76,'75.33')
plt.text(5.8,61,'60.28')
plt.text(5.8,40,'38.81')

ax.axhline(y=n1, color='black', linestyle='--', label='MMN')
ax.axhline(y=n2, color='black', linestyle='--' )
ax.axhline(y=n3, color='black', linestyle='--' )

plt.text(0.8,66,'65.05')
plt.text(0.8,49.2,'48.59')
plt.text(0.8,30,'29.26')

plt.xlabel('Layers of DTFNet',fontsize=12)
plt.ylabel('R@1',fontsize=12)
plt.ylim(18,80)
# 添加图例
plt.legend(loc='lower right',fontsize=12)
# plt.grid(True)

plt.savefig('gnn_layers.pdf', format='pdf', dpi=300)
plt.show()
